# %%
from opensky_api_ISAE import * 
import json
import numpy as np
import matplotlib.pyplot as plt
from time import gmtime, strftime
timeInSeconds = 1429617601
print(strftime("%a, %d %b %Y %H:%M:%S +0000", gmtime( timeInSeconds )))
api = OpenSkyApi()
json_string2 = api.get_states()
data2 = json.loads(json_string2)
print(data)

def funcs(data):
    time=data['time']
    print(time)
    places=data['states']
    print(places)
    for i in places:   
        heading=i['heading']
        icao24=i['icao24']
        time_velocity=i['time_velocity']
        velocity=i['velocity']
        origin_country=i['origin_country']
        altitude=i['altitude']
        time_position=i['time_position']
        longitude=i['longitude']
        sensors=i['sensors']
        vertical_rate=i['vertical_rate']
        latitude=i['latitude']
        callsign=i['callsign']
        on_ground=i['on_ground']
        print("\n")
        print(heading)
        print(icao24)
        print(time_velocity)
        print(velocity)
        print(origin_country)
        print(altitude)
        print(time_position)
        print(longitude)
        print(sensors)
        print(vertical_rate)
        print(latitude)
        print( callsign)
        print(on_ground)
        print("\n")
        
def functions(observation,prop):
    chk=observation[prop]
    if chk is not None:
        return chk
    
    
A=functions(data['states'][0],'icao24')    
print(A)

# Operating on the bigger file



# The number of flights are 

def flight(observation):
    flight_count=0
    for i in range(0,len(observation)):
        if functions(observation[i],'on_ground')==False:
            flight_count+=1
    return flight_count

flights=flight(data2['states'])
print("THE NUMBER OF AIRCRAFT FLYING ARE :"+str(flights))
 
# The different countries are 
    
def country(observation):
    L=[]
    for i in  range(0,len(observation)):
        L.append(functions(observation[i],'origin_country'))
    newl=set(L)
    return newl

def timepos(observation):
    L=[]
    for i in  range(0,len(observation)):
        dat=functions(observation[i],'time_position')
        if dat is not None:
            L.append(dat) 
    L.sort()
    early=L[0]
    late=L[len(L)-1]
    print("EARLIEST TIME :")
    print(strftime("%a, %d %b %Y %H:%M:%S +0000", gmtime( early )))
    print("LATEST TIME : ")
    print(strftime("%a, %d %b %Y %H:%M:%S +0000", gmtime( late )))
    
# Histogram

def hist(observation):
    dat=[]
    for i in  range(0,len(observation)):
        dat2=functions(observation[i],'altitude')
        if dat2 is not None:
             dat.append(dat2)
    dat.sort()
    print(dat)
    H=np.array(dat)
    A=min(H)
    B=max(H)
    bi=np.arange(A,B,100)
    print(H)
    print(bi)
    hist, bin_edges = np.histogram(H, density=True)
    plt.hist(H, bins=bi)
    plt.title("Number of flights vs Altitute")
    plt.show()
    
    
        
listofcountry=country(data2['states'])
print(listofcountry)
timepos(data2['states'])
hist(data2['states'])

# Google maps
import requests
import shutil

# set the ISAE proxy
proxyDict={ 'http' : 'http://proxy.isae.fr:3128', 'https' : 'https://proxy.isae.fr:3128'}


# positions
latitude1 = 41.42
longitude1 = 1.30


latitude2 =  43.68
longitude2 = 1.55


# Google maps
MAPS_API = "http://maps.google.com/maps/api/staticmap?"



# creation of a string to be included in the request parameters
markers = []
markers.append(str(latitude1) + "," + str(longitude1))
markers.append(str(latitude2) + "," + str(longitude2))
print(markers)
          

# function to print the number of flights in a given area
def flightmap(observation):
    for i in  range(0,len(observation)):
        LA=functions(observation[i],'latitude')
        LO=functions(observation[i],'longitude')
        if LA is not None and LO is not None:
              if LA<=43.68 and LA>=41.42 and LO<=1.55 and LO>=1.30:
                    markers.append(str(LA) + "," + str(LO))
                    print(observation[i])
            
      
            

 
flightmap(data2['states'])
print(markers)
                
params = ({'center' : 'Toulouse', 'sensor' : 'false', 'size' : '640x640', 
                             'markers' : '|'.join(markers), 
                           })                

# create the file myMap
r = requests.get(MAPS_API,  params=params , proxies=proxyDict, stream=True)
if r.status_code == 200:
    with open('MAPTOULOUSE.png', 'wb') as f:
        r.raw.decode_content = True
        shutil.copyfileobj(r.raw, f)
# Out:
# Tue, 21 Apr 2015 12:00:01 +0000
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# C:\Users\HP PC\Anaconda3\lib\site-packages\requests\packages\urllib3\connection.py in _new_conn(self)
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#
# C:\Users\HP PC\Anaconda3\lib\site-packages\requests\packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      82     if err is not None:
# ---> 83         raise err
#      84
#
# C:\Users\HP PC\Anaconda3\lib\site-packages\requests\packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      72                 sock.bind(source_address)
# ---> 73             sock.connect(sa)
#      74             return sock
#
# ...
